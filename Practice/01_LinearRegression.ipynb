# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_california_housing
# from sklearn.metrics import mean_squared_error, r2_score
# from sklearn.linear_model import LinearRegression
# from sklearn.model_selection import train_test_split

# %%
plt.show()

# %%
data = fetch_california_housing()

# %%
data

# %%
df = pd.DataFrame(data.data, columns=data.feature_names)

# %%
X = df.iloc[:, 0]
X
# Out:
# 0        8.3252
# 1        8.3014
# 2        7.2574
# 3        5.6431
# 4        3.8462
#           ...
# 20635    1.5603
# 20636    2.5568
# 20637    1.7000
# 20638    1.8672
# 20639    2.3886
# Name: MedInc, Length: 20640, dtype: float64

# %%
df.head(2)
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127    1.02381       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137    0.97188      2401.0  2.109842     37.86
#
#    Longitude
# 0    -122.23
# 1    -122.22

# %%
df['MedInc'].ndim
# Out:
# 1

# %%
y = data.target
y
# Out:
# array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894])

# %%
x = df[['MedInc']]
print(x.ndim)
print(x)
# Out:
# 2
#        MedInc
# 0      8.3252
# 1      8.3014
# 2      7.2574
# 3      5.6431
# 4      3.8462
# ...       ...
# 20635  1.5603
# 20636  2.5568
# 20637  1.7000
# 20638  1.8672
# 20639  2.3886
#
# [20640 rows x 1 columns]

# %%
import seaborn as sns
plt.figure(figsize=(10, 8))
sns.scatterplot(data=df, x='MedInc', y=y)
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
print("")

# %%
X_train  # Feature
# Out:
#        MedInc
# 14196  3.2596
# 8267   3.8125
# 17445  4.1563
# 14265  1.9425
# 2271   3.5542
# ...       ...
# 11284  6.3700
# 11964  3.0500
# 5390   2.9344
# 860    5.7192
# 15795  2.5755
#
# [16512 rows x 1 columns]

# %%
# X_train.values

# %%
# X_train = X_train.values.reshape(-1, 1)
# X_test = X_test.values.reshape(-1, 1)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# y = mx +c

# %%
model.coef_
# Out:
# array([0.41933849])

# %%
model.intercept_
# Out:
# 0.444597291690787

# %%
# y = 0.41933849 * x + 0.444597291690787

# %%
model.predict()

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([1.14958917, 1.50606882, 1.90393718, ..., 4.31500772, 1.612455  ,
#        1.93412956])

# %%
model.score(X_test, y_test)
# Out:
# 0.45885918903846656

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f"Mean Square error: ", mse)
print(f"R2 score: ", r2)
print(f"Slope(m) {model.coef_[0]:.2f}")
print(f"Intercept(c)  {model.intercept_:.2f}")
# Out:
# Mean Square error:  0.7091157771765548
# R2 score:  0.45885918903846656
# Slope(m) 0.42
# Intercept(c)  0.44

# %%
plt.scatter(X_test, y_test, label='Actual')
plt.scatter(X_test, y_pred, label='Prediction')
plt.xlabel('MedInc')
plt.ylabel('House prices $100k.')
plt.title('Linear Regression: Income → Price')
plt.legend()
plt.show()

# %%
# df.corr()

# %% [raw]
# # Observation
# =0.42×MedInc+0.44

# %%
y_pred = model.predict(x)

# %%
import seaborn as sns
plt.figure(figsize=(10, 8))
sns.scatterplot(data=df, x='MedInc', y=y, label='Actual')
plt.plot(x, y_pred, color='red', label='Predicted')
plt.legend()
plt.show()

# %%
plt.s
